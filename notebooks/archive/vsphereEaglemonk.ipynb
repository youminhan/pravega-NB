# %%
import pandas
from IPython.display import display, clear_output
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy import stats
import numpy as np
from praveganb.idracdemo import *
from praveganb.idracdemo import IdracData as VsphereData
import seaborn as sns
# %matplotlib inline

# %%
vspheredata = VsphereData(scope='vsphere', stream='vmware', gateway='10.243.37.84:80')

# %%
stream_info = vspheredata.get_stream_start_end()
print('Start: {0}'.format(stream_info[0]))
print('End: {0}'.format(stream_info[1]))
# Out:
# Start: H4sIAAAAAAAAADOwKisuyEgtStUvyy1PLEq1MgBBAJDxAa0WAAAA
# End: H4sIAAAAAAAAADOwKisuyEgtStUvyy1PLEq1MgBCY1NTUwsgsjACAERBYhcfAAAA

# %%
metrics = vspheredata.get_metric_from_vsphere(stream_info[0])
data  = dict.fromkeys(['MemoryUsage', 'CPUUsage', 'StorageUsage'], dict())
rackLabel = "eaglemonk"
vcenter = "vcenter.{0}.local".format(rackLabel)
datastores = ["vsanDatastore"] #, "isilon-shared-n1"]
for k, v in data.items():
    data[k] = pandas.DataFrame()
for _metric in metrics:
    clear_output(wait=True)
    df = pandas.json_normalize([metric for metric in _metric['metrics'] if metric['name'] == 'vsphere_host_mem'])
    df1 = pandas.json_normalize([metric for metric in _metric['metrics'] if metric['name'] == 'vsphere_host_cpu'])
    df2 = pandas.json_normalize([metric for metric in _metric['metrics'] if metric['name'] == 'vsphere_datastore_disk'])
    
    
    if 'timestamp' in df.keys():
        df['timestamp'] = pandas.to_datetime(df['timestamp'], unit='s')
        df.set_index('timestamp', inplace=True)
        df = df[(df["tags.vcenter"] == vcenter) & (df["tags.clustername"] == "compute")]
        data['MemoryUsage'] = data['MemoryUsage'].append(df)
    if 'timestamp' in df1.keys():
        df1['timestamp'] = pandas.to_datetime(df1['timestamp'], unit='s')
        df1.set_index('timestamp', inplace=True)
        df1 = df1[(df1["tags.vcenter"] == vcenter) & (df1["tags.clustername"] == "compute")]
        data['CPUUsage'] = data['CPUUsage'].append(df1)
    if 'timestamp' in df2.keys():
        df2['timestamp'] = pandas.to_datetime(df2['timestamp'], unit='s')
        df2.set_index('timestamp', inplace=True)
        df2 = df2[(df2["tags.vcenter"] == vcenter) & (df2["tags.source"].isin(datastores))]
        #  mean("used_latest") * (100 / mean("capacity_latest")
        df2["fields.usage_average"] = df2["fields.used_latest"] * (100/df2["fields.capacity_latest"])
        data['StorageUsage'] = data['StorageUsage'].append(df2)
    fig, axes = plt.subplots(nrows=len(data), ncols=1)
    
    i = 0
    for k, v in data.items():
        if data[k].empty:
            continue
        #data[k].groupby('tags.source')['fields.usage_average'].mean().plot(ax=axes[i], figsize=(20,10), kind='bar')
        data[k].groupby('tags.source')['fields.usage_average'].plot(ax=axes[i], figsize=(20,10), grid=True)

        axes[i].set_ylabel(k)
        if i == 0 :
            axes[i].set_title(rackLabel)
        axes[i].legend(loc='center left')
        i+=1
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-020151ea4fbc> in <module>
#       6 for k, v in data.items():
#       7     data[k] = pandas.DataFrame()
# ----> 8 for _metric in metrics:
#       9     clear_output(wait=True)
#      10     df = pandas.json_normalize([metric for metric in _metric['metrics'] if metric['name'] == 'vsphere_host_mem'])
#
# ~/pravega-nb/notebooks/praveganb/idracdemo.py in get_metric_from_vsphere(self, from_stream_cut)
#     115         from_stream_cut = pravega.pb.StreamCut(text=from_stream_cut)
#     116         read_events = self.unindexed_stream.read_events_from_stream(from_stream_cut)
# --> 117         for i, event in enumerate(read_events):
#     118             yield(dict(event))
#     119
#
# ~/pravega-nb/notebooks/praveganb/pravega_stream.py in <genexpr>(.0)
#      61     def read_events_from_stream(self, from_stream_cut=None, to_stream_cut=None, stop_at_tail=False):
#      62         read_events = self.read_events(from_stream_cut, to_stream_cut, stop_at_tail=stop_at_tail)
# ---> 63         return (self.read_event_tojson(read_event) for read_event in read_events)
#      64
#      65     def play_stream(self, from_stream_cut=None, to_stream_cut=None):
#
# ~/pravega-nb/notebooks/praveganb/pravega_stream.py in ignore_non_events(read_events)
#       6
#       7 def ignore_non_events(read_events):
# ----> 8     for read_event in read_events:
#       9         if len(read_event.event) > 0:
#      10             yield read_event
#
# /opt/conda/lib/python3.7/site-packages/grpc/_channel.py in __next__(self)
#     414
#     415     def __next__(self):
# --> 416         return self._next()
#     417
#     418     def _next(self):
#
# /opt/conda/lib/python3.7/site-packages/grpc/_channel.py in _next(self)
#     695                      and self._state.code is not None))
#     696
# --> 697             _common.wait(self._state.condition.wait, _response_ready)
#     698             if self._state.response is not None:
#     699                 response = self._state.response
#
# /opt/conda/lib/python3.7/site-packages/grpc/_common.py in wait(wait_fn, wait_complete_fn, timeout, spin_cb)
#     137     if timeout is None:
#     138         while not wait_complete_fn():
# --> 139             _wait_once(wait_fn, MAXIMUM_WAIT_TIMEOUT, spin_cb)
#     140     else:
#     141         end = time.time() + timeout
#
# /opt/conda/lib/python3.7/site-packages/grpc/_common.py in _wait_once(wait_fn, timeout, spin_cb)
#     102
#     103 def _wait_once(wait_fn, timeout, spin_cb):
# --> 104     wait_fn(timeout=timeout)
#     105     if spin_cb is not None:
#     106         spin_cb()
#
# /opt/conda/lib/python3.7/threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
